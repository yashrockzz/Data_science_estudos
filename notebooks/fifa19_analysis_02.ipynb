# %%
import pandas as pd

# Teste com latin1
df = pd.read_csv("../data/fifa.csv", encoding="latin1")
# df = pd.read_csv("../data/fifa.csv", encoding="ISO-8859-1")

df

# %%
df.loc[df['Nationality'] == 'Brazil']
#Filtra por jogadores do Brasil

# %%
df.loc[df['Age'] == 23]
#Filtra por jogadores de 23 anos (dados de 2019)

# %%
df.sort_values('Age', ascending = False)
#Organiza pelos mais velhos
# Out:
#        Unnamed: 0      ID           Name   Age  \
# 4741         4741  140029       O. Pérez  45.0
# 17726       17726   51963      T. Warner  44.0
# 18183       18183   53748  K. Pilkington  44.0
# 10545       10545  140183    S. Narazaki  42.0
# 1120         1120  156092      J. Villar  41.0
# ...           ...     ...            ...   ...
# 18106       18106  243685      J. Cleary  16.0
# 18204       18204  241638      B. Worman  16.0
# 18166       18166  243621       N. Ayéva  16.0
# 18206       18206  246269      G. Nugent  16.0
# 11             11  182521       T. Kroos   NaN
#
#                                                 Photo          Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png               Mexico
# 17726   https://cdn.sofifa.org/players/4/19/51963.png    Trinidad & Tobago
# 18183   https://cdn.sofifa.org/players/4/19/53748.png              England
# 10545  https://cdn.sofifa.org/players/4/19/140183.png                Japan
# ...
